# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=sns.load_dataset('tips')

# %%
sns.load_dataset
# Out:
# <function seaborn.utils.load_dataset(name, cache=True, data_home=None, **kws)>

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.shape
# Out:
# (244, 7)

# %%
sns.scatterplot(x='total_bill',y='tip',data=df)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(x='total_bill',y='tip',hue='smoker',data=df)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(x='total_bill',y='tip',hue='sex',data=df)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(x='total_bill',y='tip',hue='smoker',style='sex',data=df)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(x='total_bill',y='tip',hue='smoker',style='sex',size='size',data=df)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.relplot(x='total_bill',y='tip',kind='scatter',data=df)

# %%
cat plots

# %%
df.sample(5)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 98        21.01  3.00    Male    Yes   Fri  Dinner     2
# 204       20.53  4.00    Male    Yes  Thur   Lunch     4
# 201       12.74  2.01  Female    Yes  Thur   Lunch     2
# 71        17.07  3.00  Female     No   Sat  Dinner     3
# 39        31.27  5.00    Male     No   Sat  Dinner     3

# %%
sns.catplot(x='day',y='tip',kind='strip',data=df)

# %%
sns.catplot(x='day',y='tip',kind='strip',hue='smoker',data=df)

# %%
sns.catplot(x='day',y='tip',kind='strip',jitter=0.5,data=df)

# %%
sns.catplot(x='day',y='tip',data=df,kind='swarm')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 8.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.catplot(x='day',y='tip',data=df,kind='swarm',hue='sex')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 8.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.boxplot(df['tip'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='tip'>

# %%
sns.catplot(x='day',y='total_bill',kind='box',data=df,)

# %%
sns.catplot(x='day',y='total_bill',kind='box',data=df,hue='sex')

# %%
sns.catplot(x='day',y='total_bill',kind='box',data=df,hue='smoker')

# %%
sns.catplot(x='day',y='total_bill',kind='violin',data=df,)

# %%
sns.catplot(x='day',y='total_bill',kind='violin',data=df,hue='sex')

# %%
sns.catplot(x='day',y='total_bill',kind='violin',data=df,hue='sex',split=True)

# %%
sns.violinplot(x='day',y='total_bill',data=df,hue='sex',split=True)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>
